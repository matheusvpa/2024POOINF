// %% [markdown]
// # Você é desafiado a criar uma classe em Java chamada ExercicioVariaveis que declare e inicialize variáveis de todos os tipos primitivos disponíveis na linguagem Java. Além disso, a classe deve utilizar caracteres especiais em algumas strings para demonstrar o uso adequado desses caracteres.
//
// Siga as instruções abaixo:
//
// Declare e inicialize variáveis dos seguintes tipos primitivos:
//
// int
// long
// float
// double
// char
// boolean
// byte
// short
// Exiba os valores das variáveis utilizando System.out.println.
//
// Utilize caracteres especiais em algumas strings para representar:
//
// Caractere de nova linha (\n)
// Caractere de tabulação (\t)
// Caractere de aspas duplas (")
// Caractere de barra invertida (\\)
// Certifique-se de que o código compila e execute corretamente.

// %%
//public class ExerciciosVariaveis {
   // public static void main(String args[]){
        int numerocasa = 20; 
        System.out.println(numerocasa);

        long telefone = 9998999999l;
        System.out.println(telefone);

        float nota = 8.9f;
        System.out.println(nota);

        double notadetalhada = 8.90;
        System.out.println(notadetalhada);

        char conceito = 'A';
        System.out.println(conceito);

        boolean aprovado = true;
        System.out.println(aprovado);

        byte ddd = 45;
        System.out.println(ddd);

        short dd = 55;
        System.out.println(dd);

    // especiais Caractere de nova linha (\n) Caractere de tabulação (\t) Caractere de aspas duplas (") Caractere de barra invertida (\) Certifique-se de que o código compila e execute corretamente.
        System.out.println("nota \n conceito");
        System.out.println("nota \t conceito");
        System.out.println("nota \n 'conceito'");
        System.out.println("nota \'conceito\'");
        System.out.println("Digite nessa sequência: DD\\DDD\\TELEFONE");
  //  }
//}
// Out:
// 20
// 9998999999
// 8.9
// 8.9
// A
// true
// 45
// 55
// nota
//  conceito
// nota 	 conceito
// nota
//  'conceito'
// nota 'conceito'
// Digite nessa sequência: DD\DDD\TELEFONE
// null
